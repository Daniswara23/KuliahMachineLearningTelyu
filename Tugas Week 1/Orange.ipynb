# %% [markdown]
# Masukkan File ke dalam canvas lalu pilih dataset salary yang sudah diDownload
#
# Setelah itu ganti role YearsExperience menjadi feature dan Salary menjadi target

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lalu gunakan Data Table untuk melihat isi dari file Dataset tersebut

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Setelah itu masukkan Linear Regression dan hubungkan dengan File, lalu masukkan Test and Score dan hubungkan dengan File dan LinearRegression untuk melihat hasil dari data tersebut
#
# Pada kolom MSE Nilai yang ditampilkan merupakan nilai R2 maka nilai yang ada besar, pada RMSE merupakan nilai offset yang dihasilkan dari model yang dibuat dalam plainvalue.
#
# Sedangkan pada MAPE merupakan persentase offset yang dihasilkan sebesar 7.1%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Setelah itu untuk memvisualisasikannya bisa menggunakan Scatter Plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)
