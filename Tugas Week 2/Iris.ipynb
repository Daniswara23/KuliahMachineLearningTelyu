# %% [markdown]
# buat file csv dan atur species sebagai target

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Buat data table dan dihubungkan ke datasheet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# buat logistic regression

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Buat scatter plot untuk menghubungkan dan menampilkan data hasil regresi

# %% [markdown]
# ![image.png](data:image/png;base64,...)
